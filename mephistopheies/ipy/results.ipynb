# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("dark")
plt.rcParams['figure.figsize'] = 16, 12
import pandas as pd
from tqdm import tqdm_notebook
import io
from PIL import Image
from glob import glob
import os

import torch

# %%
def view_model(model_path):
    checkpoint = torch.load(model_path)
    print(checkpoint['epoch'])
    for k, v in sorted(checkpoint['cfg'].items(), key=lambda t: t[0]):
        print('%s = %s' % (k, str(v)))

    print('Loss train: %0.8f' % checkpoint['loss_train'][-1])
    print('Acc train: %0.8f' % checkpoint['acc_train'][-1])
    print('Loss val: %0.8f' % checkpoint['loss_val'][-1])
    print('Acc val: %0.8f' % checkpoint['acc_val'][-1])
        
    plt.plot(checkpoint['loss_train'], 'r', label='loss train')
    plt.plot(checkpoint['acc_train'], 'r--', label='acc train')
    plt.plot(checkpoint['loss_val'], 'g', label='loss val')
    plt.plot(checkpoint['acc_val'], 'g--', label='acc val')
    for i in range(1, 1 + int(np.floor(checkpoint['epoch']/checkpoint['cfg']['lr_scheduler_step_size']))):
        plt.axvline(i*checkpoint['cfg']['lr_scheduler_step_size'] - 1, c='b', alpha=0.5)
    plt.legend()
    plt.show()

# %% [markdown]
# - TLoss:
# - TAcc:
# - VLoss:
# - VAcc:
# - VAcc2:
# - VAcc3:
# - manip:
# - unalt:
# - total:

# %% [markdown]
# # Single

# %% [markdown]
# ## ResNetDenseFC34/256_random_aug_kaggle_10_pretrained_zfc_flickr_noval_nocenter
# - TLoss:
# - TAcc:  0.969
# - VLoss:
# - VAcc:
# - VAcc2: 0.9653
# - VAcc3: 0.9848
# - manip:
# - unalt:
# - total: 0.929
# - total balanced: 0.962

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/ResNetDenseFC34/256_random_aug_kaggle_10_pretrained_zfc_flickr_noval_nocenter/checkpoint.tar')
# Out:
# 91
# __val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# batch_size_train = 11
# batch_size_val = 15
# criterion_params = None
# criterion_type = CrossEntropyLoss
# crop_center_size = 3072
# crop_size = 256
# do_hard_aug = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 25
# model_path = None
# model_type = ResNetDenseFC34_pretrained_zfc
# momentum = 0.9
# n_classes = 10
# n_crops_search_train = None
# n_crops_train = 13
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac/
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 128
# train_list_flickr = /home/mephistopheies/storage2/data/camera-model-id/extra_data/train_flickr_top300.tsv
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train_all.tsv
# train_list_pseudo_npz = None
# val_path = None
# ...

# %% [markdown]
# ## ResNetDenseFC34/256_pretrained_random_aug_kaggle_10_flickr_noval
# - TLoss:
# - TAcc:
# - VLoss:
# - VAcc:
# - VAcc2: 0.9761
# - VAcc3: 0.9968
# - manip:
# - unalt:
# - total: 0.891

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/ResNetDenseFC34/256_pretrained_random_aug_kaggle_10_flickr_noval/checkpoint.tar')
# Out:
# 59
# __val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# batch_size_train = 11
# batch_size_val = 15
# criterion_params = None
# criterion_type = CrossEntropyLoss
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 25
# model_path = None
# model_type = ResNetDenseFC34_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_search_train = None
# n_crops_train = 14
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac/
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 128
# train_list_flickr = /home/mephistopheies/storage2/data/camera-model-id/extra_data/train_flickr_top300.tsv
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train_all.tsv
# train_list_pseudo_npz = None
# val_path = None
# ...

# %% [markdown]
# ## ResNetDenseFC34/256_pretrained_random_aug_kaggle_1005_weightclasses
# - TLoss:
# - TAcc:
# - VLoss:
# - VAcc:  0.9756
# - VAcc2: 0.9752
# - VAcc3: 0.9937
# - manip:
# - unalt:
# - total:

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/ResNetDenseFC34/256_pretrained_random_aug_kaggle_1005_weightclasses/best_model.tar')
# Out:
# 301
# batch_size_train = 11
# batch_size_val = 15
# criterion_params = {'weight':
#  1.1822
#  1.7358
#  1.0511
#  1.0000
#  1.1449
#  1.1322
#  1.0638
#  1.3516
#  2.6926
#  1.0908
# [torch.FloatTensor of size 10]
# }
# criterion_type = CrossEntropyLoss
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = ResNetDenseFC34_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_search_train = None
# n_crops_train = 9
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_msi/
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# train_list_pseudo_npz = None
# ...

# %% [markdown]
# ## ResNetDenseFC34/256_random_aug_kaggle_1005_pretrained_zfc
# - TLoss:
# - TAcc:
# - VLoss:
# - VAcc:  0.98098764
# - VAcc2: 0.9773
# - VAcc3: 0.9924
# - manip:
# - unalt:
# - total:

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/ResNetDenseFC34/256_random_aug_kaggle_1005_pretrained_zfc/best_model.tar')
# Out:
# 256
# batch_size_train = 11
# batch_size_val = 15
# criterion_params = None
# criterion_type = CrossEntropyLoss
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = ResNetDenseFC34_pretrained_zfc
# momentum = 0.9
# n_classes = 10
# n_crops_search_train = None
# n_crops_train = 14
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac/
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# train_list_pseudo_npz = None
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.01619938
# Acc train: 0.99533872
# Loss val: 0.06156307
# Acc val: 0.98098764

# %% [markdown]
# ## Vgg19Head_E_2b_bn/256_do_random_aug_kaggle_05
# - TLoss: 0.258575
# - TAcc:  0.9264
# - VLoss: 0.209841
# - VAcc:  0.9442
# - VAcc2: 0.9449
# - VAcc3: 0.988
# - manip: 0.239
# - unalt: 0.653
# - total: 0.892

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/Vgg19Head_E_2b_bn__bak/256_do_random_aug_kaggle_05/best_model.tar')
# Out:
# 207
# batch_size_train = 5
# batch_size_val = 15
# crop_center_size = 1520
# crop_size = 256
# do_equalize_v_hist = False
# do_hsv_convert = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = /home/mephistopheies/storage2/data/camera-model-id/models/Vgg19Head_E_3b_bn/256/best_model.tar
# model_type = Vgg19Head_E_3b_bn
# momentum = 0.9
# n_classes = 10
# n_crops_train = 7
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_msi
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.25857507
# Acc train: 0.92640000
# Loss val: 0.20984081
# Acc val: 0.94424690

# %% [markdown]
# ## resnet18fc/256_pretrained
# - TLoss: 0.003547
# - TAcc:  0.9991
# - VLoss: 0.027815
# - VAcc:  0.9915
# - VAcc2: 0.9914
# - VAcc3: 0.996
# - manip:
# - unalt: 0.634
# - total:

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet18fc/256_pretrained/best_model.tar')
# Out:
# 211
# batch_size_train = 9
# batch_size_val = 50
# crop_center_size = 1520
# crop_size = 256
# do_equalize_v_hist = False
# do_hsv_convert = False
# do_random_aug_kaggle = False
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = resnet18fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 25
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.00354747
# Acc train: 0.99910472
# Loss val: 0.02781542
# Acc val: 0.99145681

# %% [markdown]
# ## resnet18fc/256_pretrained_random_aug_kaggle_10
# - TLoss: 0.013470
# - TAcc:  0.9959
# - VLoss: 0.084618
# - VAcc:  0.9739
# - VAcc2: 0.9732
# - VAcc3: 0.9933
# - manip: 0.253
# - unalt: 0.639
# - total: 0.892

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet18fc/256_pretrained_random_aug_kaggle_10/best_model.tar')
# Out:
# 218
# batch_size_train = 9
# batch_size_val = 50
# crop_center_size = 1520
# crop_size = 256
# do_equalize_v_hist = False
# do_hsv_convert = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = resnet18fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 25
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac
# p_random_aug_kaggle = 1.0
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 6
# Loss train: 0.01346973
# Acc train: 0.99593926
# Loss val: 0.08461804
# Acc val: 0.97387656

# %% [markdown]
# ## resnet18fc/384_pretrained_random_aug_kaggle_10
# - TLoss: 0.004013
# - TAcc:  0.9987
# - VLoss: 0.043055
# - VAcc:  0.9872
# - VAcc2: 0.9872
# - VAcc3: 0.9964
# - manip: 0.251
# - unalt: 0.63
# - total: 0.881

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet18fc/384_pretrained_random_aug_kaggle_10/best_model.tar')
# Out:
# 39
# batch_size_train = 9
# batch_size_val = 10
# crop_center_size = 1520
# crop_size = 384
# do_equalize_v_hist = False
# do_hsv_convert = False
# do_random_aug_kaggle = True
# learning_rate = 0.01
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 25
# model_path = /home/mephistopheies/storage2/data/camera-model-id/models/resnet18fc/256_pretrained_random_aug_kaggle_10/best_model.tar
# model_type = resnet18fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 12
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac
# p_random_aug_kaggle = 1.0
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 6
# Loss train: 0.00401275
# Acc train: 0.99866774
# Loss val: 0.04305480
# Acc val: 0.98722223

# %% [markdown]
# ## resnet18fc/128_pretrained_random_aug_kaggle_10
# - TLoss: 0.04809029
# - TAcc:  0.9834
# - VLoss: 0.2041
# - VAcc:  0.9367
# - VAcc2: 0.9376
# - VAcc3: 0.9928
# - manip: 0.251
# - unalt: 0.641
# - total: 0.892

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet18fc/128_pretrained_random_aug_kaggle_10/best_model.tar')
# Out:
# 76
# batch_size_train = 9
# batch_size_val = 25
# crop_center_size = 1520
# crop_size = 128
# do_equalize_v_hist = False
# do_hsv_convert = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 25
# model_path = /home/mephistopheies/storage2/data/camera-model-id/models/resnet18fc/256_pretrained_random_aug_kaggle_10/best_model.tar
# model_type = resnet18fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 108
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac
# p_random_aug_kaggle = 1.0
# step_crop_val = 64
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 6
# Loss train: 0.04809029
# Acc train: 0.98348725
# Loss val: 0.20416032
# Acc val: 0.93675283

# %% [markdown]
# ## resnet34fc/256_pretrained_random_aug_kaggle_10
# - TLoss: 0.01484496
# - TAcc:  0.9951
# - VLoss: 0.1005
# - VAcc:  0.9673
# - VAcc2: 0.9665
# - VAcc3: 0.9928
# - manip: 0.256
# - unalt: 0.649
# - total: 0.905

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet34fc/256_pretrained_random_aug_kaggle_10/best_model.tar')
# Out:
# 260
# batch_size_train = 9
# batch_size_val = 15
# crop_center_size = 1520
# crop_size = 256
# do_equalize_v_hist = False
# do_hsv_convert = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = resnet34fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 12
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_msi
# p_random_aug_kaggle = 1.0
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 6
# Loss train: 0.01484496
# Acc train: 0.99510393
# Loss val: 0.10058653
# Acc val: 0.96735801

# %% [markdown]
# ## resnet18fc/256_pretrained_random_aug_kaggle_10_do_hard_aug_05
# - TLoss: 0.0277
# - TAcc:  0.9905
# - VLoss: 0.1283
# - VAcc:  0.9615
# - VAcc2: 0.9618
# - VAcc3: 0.9942
# - manip: 0.256
# - unalt: 0.638
# - total: 0.894

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet18fc/256_pretrained_random_aug_kaggle_10_do_hard_aug_05/best_model.tar')
# Out:
# 206
# batch_size_train = 9
# batch_size_val = 20
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = True
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = /home/mephistopheies/storage2/data/camera-model-id/models/resnet18fc/256_pretrained_random_aug_kaggle_10/best_model.tar
# model_type = resnet18fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 16
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_msi
# p_hard_aug = 0.5
# p_random_aug_kaggle = 1.0
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 6
# Loss train: 0.02775063
# Acc train: 0.99050047
# Loss val: 0.12836602
# Acc val: 0.96155361

# %% [markdown]
# ## resnet50fc/256_pretrained_do_random_aug_kaggle_10
# - TLoss: 0.0358
# - TAcc:  0.9884
# - VLoss: 0.1278
# - VAcc:  0.9594
# - VAcc2: 0.96
# - VAcc3: 0.992
# - manip: 0.25
# - unalt: 0.63
# - total: 0.88

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet50fc/256_pretrained_do_random_aug_kaggle_10/best_model.tar')
# Out:
# 256
# batch_size_train = 9
# batch_size_val = 20
# crop_center_size = 1520
# crop_size = 256
# do_equalize_v_hist = False
# do_hsv_convert = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = resnet50fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 7
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac
# p_random_aug_kaggle = 1.0
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 6
# Loss train: 0.03588679
# Acc train: 0.98846640
# Loss val: 0.12787644
# Acc val: 0.95943955

# %% [markdown]
# ## resnet18fc/256_pretrained_random_aug_kaggle_10_do_hard_aug_05
# - TLoss: 0.0378
# - TAcc:  0.987
# - VLoss: 0.1388
# - VAcc:  0.9561
# - VAcc2: 0.9535
# - VAcc3: 0.9977
# - manip: 0.256
# - unalt: 0.641
# - total: 0.897

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet18fc/256_pretrained_random_aug_kaggle_10_do_hard_aug_05/best_model.tar')
# Out:
# 56
# batch_size_train = 9
# batch_size_val = 20
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = True
# do_random_aug_kaggle = True
# learning_rate = 0.01
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 25
# model_path = /home/mephistopheies/storage2/data/camera-model-id/models/resnet18fc/256_pretrained_random_aug_kaggle_10_do_hard_aug_05/best_model.tar
# model_type = resnet18fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 16
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_msi
# p_hard_aug = 1.0
# p_random_aug_kaggle = 1.0
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.03782809
# Acc train: 0.98706393
# Loss val: 0.13886636
# Acc val: 0.95614555

# %% [markdown]
# ## Vgg19Head_E_2b_bn/256_do_random_aug_kaggle_05_do_hard_aug_05
# - TLoss: 0.6865
# - TAcc:  0.7881
# - VLoss: 0.5256
# - VAcc:  0.8454
# - VAcc2: 0.8393
# - VAcc3: 0.9537
# - manip: 0.194
# - unalt: 0.582
# - total: 0.776

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/Vgg19Head_E_2b_bn/256_do_random_aug_kaggle_05_do_hard_aug_05/best_model.tar')
# Out:
# 124
# batch_size_train = 5
# batch_size_val = 20
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = True
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = Vgg19Head_E_2b_bn
# momentum = 0.9
# n_classes = 10
# n_crops_train = 10
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac
# p_hard_aug = 0.5
# p_random_aug_kaggle = 0.5
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.68657573
# Acc train: 0.78815998
# Loss val: 0.52569094
# Acc val: 0.84542775

# %% [markdown]
# ## resnet34fc/256_mml_pretrained_random_aug_kaggle_10
# - TLoss: 0.0496
# - TAcc:  0.9732
# - VLoss: 0.2461
# - VAcc:  0.8965
# - VAcc2: 0.8945
# - VAcc3: 0.9493
# - manip: 0.221
# - unalt: 0.571
# - total: 0.792

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet34fc/256_mml_pretrained_random_aug_kaggle_10/best_model.tar')
# Out:
# 279
# batch_size_train = 9
# batch_size_val = 30
# criterion_params = {'p': 1.0, 'margin': 5.0}
# criterion_type = MultiMarginLoss
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = resnet34fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 12
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac
# p_hard_aug = 0.0
# p_random_aug_kaggle = 1.0
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.04962076
# Acc train: 0.97325950
# Loss val: 0.24617424
# Acc val: 0.89659258

# %% [markdown]
# ## resnet34fc/256_pretrained_random_aug_kaggle_1005_p_hard_aug_1005
# - TLoss: 0.0441
# - TAcc:  0.9852
# - VLoss: 0.1142
# - VAcc:  0.9655
# - VAcc2: 0.9639
# - VAcc3: 0.9902
# - manip: 0.242
# - unalt: 0.626
# - total: 0.868

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet34fc/256_pretrained_random_aug_kaggle_1005_p_hard_aug_1005/best_model.tar')
# Out:
# 170
# batch_size_train = 9
# batch_size_val = 30
# criterion_params = None
# criterion_type = CrossEntropyLoss
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = True
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = resnet34fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 16
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_msi
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.04416486
# Acc train: 0.98523682
# Loss val: 0.11422644
# Acc val: 0.96553085

# %% [markdown]
# ## resnet34fc/256_860_pretrained_random_aug_kaggle_1005_p_hard_aug_1005
# - TLoss: 0.0643
# - TAcc:  0.9779
# - VLoss: 0.0762
# - VAcc:  0.9748
# - VAcc2: 0.9733
# - VAcc3: 0.9991
# - manip: 0.245
# - unalt: 0.633
# - total: 0.878

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet34fc/256_860_pretrained_random_aug_kaggle_1005_p_hard_aug_1005/best_model.tar')
# Out:
# 128
# batch_size_train = 9
# batch_size_val = 30
# criterion_params = None
# criterion_type = CrossEntropyLoss
# crop_center_size = 2000
# crop_size = 256
# do_hard_aug = True
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 25
# model_path = None
# model_type = resnet34fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 16
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_msi
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.06438869
# Acc train: 0.97794622
# Loss val: 0.07625051
# Acc val: 0.97486418

# %% [markdown]
# ## resnet34fc/256_2000_pretrained_random_aug_kaggle_1005_p_hard_aug_1005
# - TLoss: 0.0629
# - TAcc:  0.9793
# - VLoss: 0.1746
# - VAcc:  0.9443
# - VAcc2: 0.9431
# - VAcc3: 0.9893
# - manip: 0.23
# - unalt: 0.608
# - total: 0.838

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet34fc/256_2000_pretrained_random_aug_kaggle_1005_p_hard_aug_1005/best_model.tar')
# Out:
# 174
# batch_size_train = 9
# batch_size_val = 30
# criterion_params = None
# criterion_type = CrossEntropyLoss
# crop_center_size = 860
# crop_size = 256
# do_hard_aug = True
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 25
# model_path = None
# model_type = resnet34fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_train = 12
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.06296955
# Acc train: 0.97934035
# Loss val: 0.17465507
# Acc val: 0.94439505

# %% [markdown]
# ## FatNet1/256_random_aug_kaggle_1005_p_hard_aug_1005
# - TLoss: 0.0314
# - TAcc:  0.9904
# - VLoss: 0.1311
# - VAcc:  0.9575
# - VAcc2: 0.9567
# - VAcc3: 0.992
# - manip: 0.232
# - unalt: 0.624
# - total: 0.856

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/FatNet1/256_random_aug_kaggle_1005_p_hard_aug_1005/best_model.tar')
# Out:
# 205
# batch_size_train = 9
# batch_size_val = 30
# criterion_params = None
# criterion_type = CrossEntropyLoss
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = True
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = resnet34fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_search_train = 36
# n_crops_train = 12
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.03141653
# Acc train: 0.99042196
# Loss val: 0.13110743
# Acc val: 0.95758023

# %% [markdown]
# ## resnet34fc/256_pretrained_random_aug_kaggle_1005/pseudo_phase_1
# - TLoss: 0.01835125
# - TAcc:  0.9945
# - VLoss: 0.1438
# - VAcc:  0.9562
# - VAcc2: 0.957
# - VAcc3: 0.9848
# - manip: 0.246
# - unalt: 0.63
# - total: 0.876

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/resnet34fc/256_pretrained_random_aug_kaggle_1005/pseudo_phase_1/best_model.tar')
# Out:
# 187
# batch_size_train = 9
# batch_size_val = 30
# criterion_params = None
# criterion_type = CrossEntropyLoss
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = resnet34fc_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_search_train = 36
# n_crops_train = 12
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_msi/
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# train_list_pseudo_npz = /home/mephistopheies/storage2/data/camera-model-id/pseudo_labels/phase1/
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.01835125
# ...

# %% [markdown]
# ## Vgg19Head_E_2b_bn/256
# - TLoss: 0.0976
# - TAcc:  0.9734
# - VLoss: 0.1024
# - VAcc:  0.972
# - VAcc2: 0.972
# - VAcc3: 0.984
# - manip:
# - unalt: 0.647
# - total:

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/Vgg19Head_E_2b_bn/256/best_model.tar')
# Out:
# 225
# batch_size_train = 5
# batch_size_val = 15
# criterion_params = None
# criterion_type = CrossEntropyLoss
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = False
# do_random_aug_kaggle = False
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = Vgg19Head_E_2b_bn
# momentum = 0.9
# n_classes = 10
# n_crops_search_train = 36
# n_crops_train = 7
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_msi/
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# train_list_pseudo_npz = /home/mephistopheies/storage2/data/camera-model-id/pseudo_labels/phase1/
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.09761265
# ...

# %% [markdown]
# ## InceptionResNetV2/256_pretrained_random_aug_kaggle_1005
# - TLoss:
# - TAcc:
# - VLoss:
# - VAcc:
# - VAcc2: 0.9782
# - VAcc3: 0.9866
# - manip:
# - unalt:
# - total: 0.884

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/InceptionResNetV2/256_pretrained_random_aug_kaggle_1005/best_model.tar')
# Out:
# 222
# batch_size_train = 10
# batch_size_val = 10
# criterion_params = None
# criterion_type = CrossEntropyLoss
# crop_center_size = 1520
# crop_size = 320
# do_hard_aug = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = InceptionResNetV2
# momentum = 0.9
# n_classes = 10
# n_crops_search_train = None
# n_crops_train = 3
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_zotac/
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 96
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# train_list_pseudo_npz = /home/mephistopheies/storage2/data/camera-model-id/pseudo_labels/resnet34fc__256_pretrained_random_aug_kaggle_10__phase1
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# ...

# %% [markdown]
# ## ResNetDenseFC34/256_pretrained_random_aug_kaggle_1005
# - TLoss:
# - TAcc:
# - VLoss:
# - VAcc:  0.9754
# - VAcc2: 0.976
# - VAcc3: 0.9915
# - manip:
# - unalt:
# - total: 0.891

# %%
view_model('/home/mephistopheies/storage2/data/camera-model-id/models/ResNetDenseFC34/256_pretrained_random_aug_kaggle_1005/best_model.tar')
# Out:
# 152
# batch_size_train = 11
# batch_size_val = 15
# criterion_params = None
# criterion_type = CrossEntropyLoss
# crop_center_size = 1520
# crop_size = 256
# do_hard_aug = False
# do_random_aug_kaggle = True
# learning_rate = 0.1
# lr_scheduler_gamma = 0.5
# lr_scheduler_step_size = 50
# model_path = None
# model_type = ResNetDenseFC34_pretrained
# momentum = 0.9
# n_classes = 10
# n_crops_search_train = None
# n_crops_train = 9
# n_epoches = 1000
# optim_type = sgd
# out_dir = /home/mephistopheies/storage2/data/camera-model-id/tmp_msi/
# p_hard_aug_train = 1.0
# p_hard_aug_val = 0.5
# p_random_aug_kaggle_train = 1.0
# p_random_aug_kaggle_val = 0.5
# step_crop_val = 128
# train_list_path = /home/mephistopheies/storage2/data/camera-model-id/train.tsv
# train_list_pseudo_npz = None
# val_path = /home/mephistopheies/storage2/data/camera-model-id/val/
# weight_decay = 0.0
# workers = 4
# Loss train: 0.03443521
# Acc train: 0.98923445
# Loss val: 0.07532898
# Acc val: 0.97545678

# %% [markdown]
# # Two (unalt + manip)

# %% [markdown]
# ## Vgg19Head_E_3b_bn/256_do_random_aug_kaggle_05 + resnet18fc/256_pretrained_random_aug_kaggle_10
# - unalt: 0.653
# - manip: 0.253
# - total exp: 0.906
# - total balance: 0.92

# %% [markdown]
# ## Vgg19Head_E_3b_bn/256_do_random_aug_kaggle_05 + resnet34fc/256_pretrained_random_aug_kaggle_10
# - unalt: 0.653
# - manip: 0.256
# - total exp: 0.909
# - total balance: 0.922
